# %% [markdown]
# # Özellik Çıkarımı
#
# Bu notebook, görüntü, metin, kategorik ve numerik özelliklerin çıkarılması ve birleştirilmesi için kullanılır.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from pathlib import Path

sys.path.append('..')

from src.data_collection import ImageCollector
from src.feature_extraction import (
    ImageFeatureExtractor, TextFeatureExtractor,
    encode_categorical_features, normalize_numerical_features,
    fuse_features, extract_image_features, extract_text_features
)
from src.utils import load_dataset
