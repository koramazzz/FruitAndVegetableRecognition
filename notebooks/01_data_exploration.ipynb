# %% [markdown]
# # Veri Keşfi ve Analizi
#
# Bu notebook, meyve ve sebze veri setinin keşfi ve analizi için kullanılır.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import sys

# Proje kök dizinini ekle
sys.path.append('..')

from src.data_collection import ImageCollector, MetadataCollector, TextCollector
from src.utils import load_dataset, print_data_quality_report
from src.evaluation import print_similarity_report, print_outlier_report
